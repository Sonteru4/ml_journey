# %% [markdown]
# # 🧙‍♂️ Harry Potter & The Spells of Python
# Welcome to Hogwarts School of Codecraft & Wizardry!
#
# Learning Journey:
# (Refresher)
# - Variables
# - Data types
# - Input/Output
# - Functions
# - A magical mini challenge!

# %%
# 🪄 Let's create our first spell (variable)
wand = "Holly, 11 inches"
wizard_name = "Sanjana Onteru"

print(f"Welcome, {wizard_name}!")
print(f"Your wand is made of {wand}.")
# Out:
# Welcome, Sanjana Onteru!
# Your wand is made of Holly, 11 inches.

# %%
print("🧙‍♀️ Welcome to Sanjana's Enchanted Potion Parlor! 🧙‍♂️")
print("Today you'll brew a potion so magical, even Hogwarts would be envious!\n")

# Gather potion ingredients
newt_eyes = int(input("How many sparkling newt eyes would you like to add? "))
dragon_blood_ml = float(input("How many milliliters of fiery dragon blood should we pour in? "))

# Mixing the potion with magical flair
print("\nStirring the cauldron with a flick of the wand... ✨")
print(f"You've added {newt_eyes} sparkling newt eyes and {dragon_blood_ml} ml of dragon blood!")
print("The potion is bubbling mysteriously... Mischief Managed!")
# Out:
# 🧙‍♀️ Welcome to Sanjana's Enchanted Potion Parlor! 🧙‍♂️
# Today you'll brew a potion so magical, even Hogwarts would be envious!
#
# How many sparkling newt eyes would you like to add? 6
# How many milliliters of fiery dragon blood should we pour in? 55.5
#
# Stirring the cauldron with a flick of the wand... ✨
# You've added 6 sparkling newt eyes and 55.5 ml of dragon blood!
# The potion is bubbling mysteriously... Mischief Managed!

# %%
# ✨ Function to cast a spell
def cast_spell(spell_name):
    print(f"Casting {spell_name.upper()}! 💥")

cast_spell("lumos")
cast_spell("expelliarmus")
# Out:
# Casting LUMOS! 💥
# Casting EXPELLIARMUS! 💥

# %% [markdown]
# ## 🧙 Challenge: Create your own spell function!
# - Make a function called `your_spell()`
# - It should take a name and action (e.g., freeze, light, protect)
# - Print something magical!

# %%
def your_spell(name, action):
    """
    Cast a magical spell with a custom name and action.
    Example actions: freeze, light, protect, etc.
    """
    # Create a magical incantation combining the name and action.
    spell_incantation = f"{name} chants: 'Expecto {action.capitalize()}us!' and a burst of enchantment fills the room!"
    print(spell_incantation)

# Example usage:
your_spell("Sanjana", "protect")
# Out:
# Sanjana chants: 'Expecto Protectus!' and a burst of enchantment fills the room!

# %% [markdown]
# # 🧙‍♂️ Day 2: Spell Casting Loops at Hogwarts
# Topics:
# - for loops
# - while loops
# - if-else conditions
# - Hogwarts Duel mini-game

# %%
spells = ["Expelliarmus", "Stupefy", "Lumos", "Accio", "Protego"]

for spell in spells:
    print(f"Casting {spell}! ✨")
# Out:
# Casting Expelliarmus! ✨
# Casting Stupefy! ✨
# Casting Lumos! ✨
# Casting Accio! ✨
# Casting Protego! ✨

# %%
mana = 5

while mana > 0:
    print(f"You have {mana} mana left. Casting spell... 💥")
    mana -= 1

print("You're out of mana! Drink a potion 🧪")
# Out:
# You have 5 mana left. Casting spell... 💥
# You have 4 mana left. Casting spell... 💥
# You have 3 mana left. Casting spell... 💥
# You have 2 mana left. Casting spell... 💥
# You have 1 mana left. Casting spell... 💥
# You're out of mana! Drink a potion 🧪

# %%
import random

opponent = random.choice(["Draco", "Voldemort", "Bellatrix"])
print(f"You are dueling with {opponent}! 🧙‍♀️⚔️")

spells = ["Expelliarmus", "Stupefy", "Protego", "Sectumsempra"]

for round_num in range(1, 4):
    print(f"\nRound {round_num} - Choose your spell:")
    print(spells)
    
    user_spell = input("Type your spell: ")

    if user_spell in spells:
        print(f"💥 You cast {user_spell} at {opponent}!")
    else:
        print("🧹 You fumbled your wand! No spell cast.")
# Out:
# You are dueling with Bellatrix! 🧙‍♀️⚔️
#
# Round 1 - Choose your spell:
# ['Expelliarmus', 'Stupefy', 'Protego', 'Sectumsempra']
# Type your spell: stupefy
# 🧹 You fumbled your wand! No spell cast.
#
# Round 2 - Choose your spell:
# ['Expelliarmus', 'Stupefy', 'Protego', 'Sectumsempra']
# Type your spell: Protego
# 💥 You cast Protego at Bellatrix!
#
# Round 3 - Choose your spell:
# ['Expelliarmus', 'Stupefy', 'Protego', 'Sectumsempra']
# Type your spell: Expelliarmus
# 💥 You cast Expelliarmus at Bellatrix!

# %% [markdown]
# # 🔮 Bonus Challenge:
# - Add HP (Health Points) for both player and opponent
# - Reduce HP on spell hit
# - End with a win/lose message 🏆

# %% [markdown]
# # 🧪 Hogwarts Duel With HP – Final Battle Code

# %%
import random

# Setup duel
opponent = random.choice(["Draco", "Voldemort", "Bellatrix"])
print(f"You are dueling with {opponent}! 🧙‍♂️⚔️")

# Initial HP
your_hp = 100
opponent_hp = 100

# Spell list with possible damage values
spells = {
    "Expelliarmus": (10, 20),
    "Stupefy": (15, 25),
    "Protego": (0, 0),  # Defense spell
    "Sectumsempra": (20, 35)
}

# Duel begins
round_num = 1

while your_hp > 0 and opponent_hp > 0:
    print(f"\n--- Round {round_num} ---")
    print(f"Your HP: {your_hp} | {opponent}'s HP: {opponent_hp}")
    print("Available spells:", list(spells.keys()))
    
    spell = input("Choose your spell: ").strip()

    if spell in spells:
        dmg_range = spells[spell]
        if dmg_range == (0, 0):
            print("🛡️ You defended this round with Protego!")
        else:
            damage = random.randint(*dmg_range)
            opponent_hp -= damage
            print(f"💥 You hit {opponent} with {spell}, causing {damage} damage!")
    else:
        print("❌ Invalid spell. You lost your turn!")

    # Opponent attacks
    if opponent_hp > 0:
        opp_damage = random.randint(10, 25)
        your_hp -= opp_damage
        print(f"🔥 {opponent} strikes back! You lose {opp_damage} HP.")

    round_num += 1

# End Game
print("\n🏁 Duel Over!")
if your_hp > 0 and opponent_hp <= 0:
    print(f"🏆 You defeated {opponent} and won the duel!")
elif opponent_hp > 0 and your_hp <= 0:
    print(f"💀 You were defeated by {opponent}. Better luck next time!")
else:
    print("⚖️ It's a draw! Both duelers fell at the same time.")
# Out:
# You are dueling with Bellatrix! 🧙‍♂️⚔️
#
# --- Round 1 ---
# Your HP: 100 | Bellatrix's HP: 100
# Available spells: ['Expelliarmus', 'Stupefy', 'Protego', 'Sectumsempra']
# Choose your spell: stupefy
# ❌ Invalid spell. You lost your turn!
# 🔥 Bellatrix strikes back! You lose 16 HP.
#
# --- Round 2 ---
# Your HP: 84 | Bellatrix's HP: 100
# Available spells: ['Expelliarmus', 'Stupefy', 'Protego', 'Sectumsempra']
# Choose your spell: Protego
# 🛡️ You defended this round with Protego!
# 🔥 Bellatrix strikes back! You lose 25 HP.
#
# --- Round 3 ---
# Your HP: 59 | Bellatrix's HP: 100
# Available spells: ['Expelliarmus', 'Stupefy', 'Protego', 'Sectumsempra']
# Choose your spell: Expelliarmus
# 💥 You hit Bellatrix with Expelliarmus, causing 13 damage!
# 🔥 Bellatrix strikes back! You lose 22 HP.
#
# --- Round 4 ---
# Your HP: 37 | Bellatrix's HP: 87
# Available spells: ['Expelliarmus', 'Stupefy', 'Protego', 'Sectumsempra']
# Choose your spell: Sectumsempra
# ...

# %% [markdown]
# # 🧙‍♀️ Day 3: The Sorting Hat Knows All
# Today we learn:
# - If-else logic
# - Logical operators
# - Nested conditions
# - Building a custom Hogwarts Sorting Hat quiz 🎩

# %%
house = "Gryffindor"

if house == "Gryffindor":
    print("Welcome, brave soul! 🦁")
elif house == "Slytherin":
    print("Welcome, ambitious one! 🐍")
elif house == "Ravenclaw":
    print("Welcome, wise mind! 🦅")
elif house == "Hufflepuff":
    print("Welcome, kind heart! 🦡")
else:
    print("Hmm... are you a muggle? 🤔")
# Out:
# Welcome, brave soul! 🦁

# %% [markdown]
# # Sorting Hat Personality Quiz

# %%
print("🧙‍♂️ Welcome to the Sorting Hat Ceremony!")
brave = input("Do you consider yourself brave? (yes/no): ").strip().lower()
ambitious = input("Are you ambitious? (yes/no): ").strip().lower()
kind = input("Are you kind and loyal? (yes/no): ").strip().lower()
wise = input("Do you love learning and value wisdom? (yes/no): ").strip().lower()

# Decision Logic
if brave == "yes" and ambitious == "no":
    print("🦁 You're a Gryffindor!")
elif ambitious == "yes" and wise == "no":
    print("🐍 You're a Slytherin!")
elif wise == "yes" and brave == "no":
    print("🦅 You're a Ravenclaw!")
elif kind == "yes":
    print("🦡 You're a Hufflepuff!")
else:
    print("⚡ Hmm... difficult... perhaps a squib? 🤨")
# Out:
# 🧙‍♂️ Welcome to the Sorting Hat Ceremony!
# Do you consider yourself brave? (yes/no): yes
# Are you ambitious? (yes/no): yes
# Are you kind and loyal? (yes/no): yes
# Do you love learning and value wisdom? (yes/no): yes
# 🦡 You're a Hufflepuff!

# %%
print("✨ WELCOME TO THE ADVANCED SORTING HAT QUIZ ✨\nAnswer with 'a', 'b', 'c', or 'd'...\n")

# Points for each house
points = {
    "Gryffindor": 0,
    "Slytherin": 0,
    "Ravenclaw": 0,
    "Hufflepuff": 0
}

# Question 1
print("1. What would you do if you found a mysterious locked door at school?")
print("a) Try to open it with courage 🔥")
print("b) Figure out how it benefits you 💼")
print("c) Research about the door in the library 📚")
print("d) Tell a professor — safety first 🌼")
ans = input().lower()
if ans == "a":
    points["Gryffindor"] += 1
elif ans == "b":
    points["Slytherin"] += 1
elif ans == "c":
    points["Ravenclaw"] += 1
elif ans == "d":
    points["Hufflepuff"] += 1

# Question 2
print("\n2. Which magical subject excites you the most?")
print("a) Defense Against the Dark Arts 🛡️")
print("b) Potions 🧪")
print("c) Ancient Runes 📖")
print("d) Herbology 🌱")
ans = input().lower()
if ans == "a":
    points["Gryffindor"] += 1
elif ans == "b":
    points["Slytherin"] += 1
elif ans == "c":
    points["Ravenclaw"] += 1
elif ans == "d":
    points["Hufflepuff"] += 1

# Question 3
print("\n3. Choose a magical pet:")
print("a) Phoenix 🔥")
print("b) Snake 🐍")
print("c) Owl 🦉")
print("d) Badger 🦡")
ans = input().lower()
if ans == "a":
    points["Gryffindor"] += 1
elif ans == "b":
    points["Slytherin"] += 1
elif ans == "c":
    points["Ravenclaw"] += 1
elif ans == "d":
    points["Hufflepuff"] += 1

# Question 4
print("\n4. What do you value most?")
print("a) Bravery 💪")
print("b) Ambition 🧠")
print("c) Knowledge 📚")
print("d) Loyalty 💛")
ans = input().lower()
if ans == "a":
    points["Gryffindor"] += 1
elif ans == "b":
    points["Slytherin"] += 1
elif ans == "c":
    points["Ravenclaw"] += 1
elif ans == "d":
    points["Hufflepuff"] += 1

# Question 5
print("\n5. Pick a Hogwarts hangout spot:")
print("a) Gryffindor common room by the fire 🔥")
print("b) The dungeons 💀")
print("c) The library 📚")
print("d) The greenhouse 🌿")
ans = input().lower()
if ans == "a":
    points["Gryffindor"] += 1
elif ans == "b":
    points["Slytherin"] += 1
elif ans == "c":
    points["Ravenclaw"] += 1
elif ans == "d":
    points["Hufflepuff"] += 1

# Determine winner
print("\n🧙‍♂️ The Sorting Hat is thinking...\n")
final_house = max(points, key=points.get)
print(f"🎩 You belong to... {final_house.upper()}! 🏆")
# Out:
# ✨ WELCOME TO THE ADVANCED SORTING HAT QUIZ ✨
# Answer with 'a', 'b', 'c', or 'd'...
#
# 1. What would you do if you found a mysterious locked door at school?
# a) Try to open it with courage 🔥
# b) Figure out how it benefits you 💼
# c) Research about the door in the library 📚
# d) Tell a professor — safety first 🌼
# a
#
# 2. Which magical subject excites you the most?
# a) Defense Against the Dark Arts 🛡️
# b) Potions 🧪
# c) Ancient Runes 📖
# d) Herbology 🌱
# d
#
# 3. Choose a magical pet:
# a) Phoenix 🔥
# b) Snake 🐍
# c) Owl 🦉
# d) Badger 🦡
# a
#
# 4. What do you value most?
# a) Bravery 💪
# b) Ambition 🧠
# c) Knowledge 📚
# d) Loyalty 💛
# c
#
# 5. Pick a Hogwarts hangout spot:
# a) Gryffindor common room by the fire 🔥
# b) The dungeons 💀
# c) The library 📚
# d) The greenhouse 🌿
# a
#
# 🧙‍♂️ The Sorting Hat is thinking...
#
# 🎩 You belong to... GRYFFINDOR! 🏆
